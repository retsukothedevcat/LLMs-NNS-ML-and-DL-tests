# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///ecommerce.db', echo=True)

# %%
with engine.connect() as connection:
    result = connection.execute(text("SELECT 1"))
    # Fetch and print the result
    print(result.scalar()) # This should print 1 if the connection is successful
# Out:
# 2026-07-20 12:53:13,906 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2026-07-20 12:53:13,930 INFO sqlalchemy.engine.base.Engine ()
# 2026-07-20 12:53:13,938 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2026-07-20 12:53:13,940 INFO sqlalchemy.engine.base.Engine ()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4676f5828ae2> in <module>
#       1 with engine.connect() as connection:
# ----> 2     result = connection.execute(text("SELECT 1"))
#       3     # Fetch and print the result
#       4     print(result.scalar()) # This should print 1 if the connection is successful
#
# NameError: name 'text' is not defined
